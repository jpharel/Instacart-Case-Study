# %% [markdown]
# # Importing Libraries and orders_products_prior into Python

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Updating the path to include more of the folder path to make our later code cleaner
path = r"C:\Users\jphar\Instacart Basket Analysis 09-2025\02 Data"

# %%
df_ords_prior = pd.read_csv(os.path.join(path, "Original Data", "orders_products_prior.csv"), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, "Prepared Data", "orders_processed.csv"), index_col = False)

# %%
df_ords_prior
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
# [32434489 rows x 4 columns]

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# # Merging df_ords to df_ords_prior

# %%
df_ords.shape
# Out:
# (3421083, 9)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = "order_id", indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  hour_ordered_of_day  days_since_prior_order  \
# 0                   2                    8                     NaN
# 1                   2                    8                     NaN
# 2                   2                    8                     NaN
# 3                   2                    8                     NaN
# 4                   2                    8                     NaN
#
#   first_time_order  product_id  add_to_cart_order  reordered _merge
# 0              Yes         196                  1          0   both
# ...

# %%
df_merged_large["_merge"].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # Testing Merge Rate with Outer Join

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = "order_id", indicator = True, how = "outer")

# %%
df_merged_large["_merge"].value_counts()
# Out:
# _merge
# both          32434489
# left_only       206209
# right_only           0
# Name: count, dtype: int64

# %%
# Due to the instructions, we'll only consider full match data (i.e., inner joins)

df_merged_large = df_ords.merge(df_ords_prior, on = "order_id", indicator = True)

# %% [markdown]
# # Exporting Merged Dataset

# %%
df_merged_large.to_pickle(os.path.join(path, "Prepared Data", "orders_products_combined.pkl"))

# %% [markdown]
# # Merging orders_products_combined with products Dataset
