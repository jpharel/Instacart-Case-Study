# %% [markdown]
# # 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Python Data Types

# %% [markdown]
# ## 3 Calculations Resulting in 100

# %%
x = 25

# %%
y = 75

# %%
x + y
# Out:
# 100

# %%
(x * 2 + y) - x
# Out:
# 100

# %%
y + y - x - x
# Out:
# 100

# %% [markdown]
# # 2 Floating-Point Variable Division Calculations

# %%
x = 5.0

# %%
y = 20.0

# %%
y / x
# Out:
# 4.0

# %%
x / y
# Out:
# 0.25

# %% [markdown]
# # Concatenate Responses

# %%
"d" + "o" + "g"
# Out:
# 'dog'

# %%
"Hello, " + "World!"
# Out:
# 'Hello, World!'

# %%
x = "Be vewwy, vewwy quiet..."

# %%
y = "I'm hunting wabbits!"

# %%
x + y
# Out:
# "Be vewwy, vewwy quiet...I'm hunting wabbits!"

# %% [markdown]
# # Bonus Task

# %%
x * 100
# Out:
# 'Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vewwy quiet...Be vewwy, vew
# ...

# %%
z = 4

# %%
a = 5.123

# %%
type(z + a)
# Out:
# float

# %%
dataframe_name = pd.read_csv(r'folderpath\...\name.csv', index_col = False)
