# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Updating the path to include more of the folder path to make our later code cleaner
path = r"C:\Users\jphar\Instacart Basket Analysis 09-2025\02 Data"

# %%
# Practicing User Defined functions

def add_num(x,y):
    sum = x + y
    return sum

# %%
# Run function

add_num(9,11)
# Out:
# 20

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, "Prepared Data", "ords_prods_merge.pkl"))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_ordered_of_day  \
# 0   2539329        1             1                   2                    8
# 1   2539329        1             1                   2                    8
# 2   2539329        1             1                   2                    8
# 3   2539329        1             1                   2                    8
# 4   2539329        1             1                   2                    8
#
#    days_since_prior_order first_time_order  product_id  add_to_cart_order  \
# 0                     NaN              Yes         196                  1
# 1                     NaN              Yes       14084                  2
# 2                     NaN              Yes       12427                  3
# 3                     NaN              Yes       26088                  4
# 4                     NaN              Yes       26405                  5
#
# ...

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
def price_label(row):

    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# C:\Users\jphar\AppData\Local\Temp\ipykernel_2404\935325922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\jphar\AppData\Local\Temp\ipykernel_2404\3192052085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
# With our testing completed we can now apply this to the greater dataframe - ords_prods_merge

ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_category'] = 'High-range product'
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_category'] = 'Mid-range product' 
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_category'] = 'Low-range product'

# %%
ords_prods_merge['price_category'].value_counts()
# Out:
# price_category
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
#Writing out your age from 30-45 manually versus with a for-loop

print("My age is 30")

for x in range (30,45):
    print("My age is %d" % (x))
# Out:
# My age is 30
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
ords_prods_merge['orders_day_of_week'].value_counts()
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge['orders_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regular busy')

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
# ...

# %%
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'hour_ordered_of_day', 'days_since_prior_order', 'first_time_order',
#        'product_id', 'add_to_cart_order', 'reordered', '_merge',
#        'product_name', 'aisle_id', 'department_id', 'prices',
#        'price_category'],
#       dtype='object')

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regular busy    22416875
# Busiest day      6204182
# Least busy       3783802
# Name: count, dtype: int64

# %%
#Verifying if the new field is accurate to the dataframe

ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 17)

# %% [markdown]
# # Task Responses

# %% [markdown]
# ### 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
#Checking which are the busiest and slowest days

ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# First I'll reuse the result variable 
result = []

# Next, I'll set up a for-loop with the conditions to account for the two busiest days (0 and 1) and the two slowest days (3 and 4)

for value in ords_prods_merge['orders_day_of_week']:
    if value == 0 or value == 1:
        result.append('Busiest days')
    elif value == 3 or value == 4:
        result.append('Slowest days')
    else:
        result.append('Regular day')

# %%
ords_prods_merge['busiest_days'] = result

# %% [markdown]
# ### 3. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
ords_prods_merge['busiest_days'].value_counts()
# Out:
# busiest_days
# Regular day     12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %%
#Verifying if the new field is accurate to the dataframe

ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# We can see here that the two busiest days accounts for nearly 36.6% of total orders, while regular days account for nearly 39.9%, and slowest days account for nearly 23.5% of total orders

# %% [markdown]
# ### 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'hour_ordered_of_day', 'days_since_prior_order', 'first_time_order',
#        'product_id', 'add_to_cart_order', 'reordered', '_merge',
#        'product_name', 'aisle_id', 'department_id', 'prices', 'price_category',
#        'busiest_day', 'busiest_days'],
#       dtype='object')

# %% [markdown]
# For figuring out the periods of time where Instacart gets the most, average, and fewest orders take place we'll need to use value_counts() to determine the frequency of orders from the hour_ordered_of_day

# %%
# With this frequency result we'll place them in 3 equal buckets

ords_prods_merge['hour_ordered_of_day'].value_counts(dropna = False)
# Out:
# hour_ordered_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
# I will make these into lists to make it easier to evaluate when using a for-loop.
# We won't need the last "bucket" because it essentially will be handled by our else clause

busy_hours = [10, 11, 14, 15, 13, 12, 16, 9]
regular_hours = [17, 8, 18, 19, 20, 7, 21, 22]

# %%
# reusing the result variable from earlier and assigning it an empty set again

result = []

for value in ords_prods_merge['hour_ordered_of_day']:
    if value in busy_hours:
        result.append('Most orders')
    elif value in regular_hours:
        result.append('Average orders')
    else:
        result.append('Fewest orders')

# %%
ords_prods_merge['busiest_period_of_day'] = result

# %%
ords_prods_merge['busiest_period_of_day'].value_counts()
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %%
ords_prods_merge['hour_ordered_of_day'].value_counts(dropna = False)
# Out:
# hour_ordered_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# When we calculate the values for both busiest_period_of_day and hour_ordered_of_day we see that these match and are successful with flagging this new field!

# %% [markdown]
# ords_prods_merge.to_pickle(os.path.join(path, "Prepared Data", "ords_prods_merge_derivations.pkl"))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)
